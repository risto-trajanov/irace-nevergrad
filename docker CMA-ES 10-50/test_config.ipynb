# %%
import os
import pandas as pd
import subprocess

# %%
p = subprocess.run("python ./target-runner.py 4 8 1101047833 yasmallbbob --name=hm --rotation=True --d=50 --budget=20   --solver=CMA-ES --scale=5.8196 --popsize_factor=5 --elitist=True --diagonal=False --fcmaes=True --random_init=False", stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')

# %%
p.replace('\r\n', '')
# Out:
# '2581.1621217457055'

# %%
out
# Out:
# b'2581.1621217457055\r\n'

# %%
os.system('python target-runner.py 4 8 1101047833 yasmallbbob --name=hm --rotation=True --d=50 --budget=20   --solver=CMA-ES --scale=5.8196 --popsize_factor=5 --elitist=True --diagonal=False --fcmaes=True --random_init=False')
# Out:
# 0

# %%
df = pd.read_csv('./instances_small_10_50.txt', delimiter=' --', header=None)
# Out:
# C:\Users\Risto\.conda\envs\newEnv\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
df.columns = ['benchmark', 'funct', 'rot', 'dim', 'budg']

# %%
df
# Out:
#        benchmark                     funct             rot   dim       budg
# 0    yasmallbbob                   name=hm  rotation=False  d=10  budget=10
# 1    yasmallbbob            name=rastrigin  rotation=False  d=10  budget=10
# 2    yasmallbbob             name=griewank  rotation=False  d=10  budget=10
# 3    yasmallbbob           name=rosenbrock  rotation=False  d=10  budget=10
# 4    yasmallbbob               name=ackley  rotation=False  d=10  budget=10
# ..           ...                       ...             ...   ...        ...
# 259  yasmallbbob               name=discus   rotation=True  d=50  budget=40
# 260  yasmallbbob            name=bentcigar   rotation=True  d=50  budget=40
# 261  yasmallbbob     name=deceptiveillcond   rotation=True  d=50  budget=40
# 262  yasmallbbob  name=deceptivemultimodal   rotation=True  d=50  budget=40
# 263  yasmallbbob        name=deceptivepath   rotation=True  d=50  budget=40
#
# [264 rows x 5 columns]

# %%
instances = []
for rec_index, rec in df.iterrows():
    instances.append(f'yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}')

# %%
df_output_new = df_output.copy()
df_output_new['instance'] = instances

# %%
df_rank = pd.read_csv('./output_with_ranks (1).csv', index_col=0)

# %%
instances = instances + ['', '']

# %%
new_df = df_rank.transpose()
new_df['instance'] = instances
new_df = new_df.transpose()

# %%
new_df.to_csv('output_with_rank.csv')

# %%
instances_series = pd.Series(instances)
instances_df = pd.DataFrame([instances_series])
pd.concat([df_rank, instances_df], ignore_index=True)
# Out:
#                                                    0  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  python target-runner.py 4 8 1101047833 yasmall...
#
#                                                    1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  python target-runner.py 4 8 1101047833 yasmall...
#
#                                                    2  \
# ...

# %%
irace_results_1 = []
for rec_index, rec in df.iterrows():
    p = subprocess.run(f'python target-runner.py 4 8 1101047833 yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}   --solver=CMA-ES --scale=0.4151 --popsize_factor=9 --elitist=False --diagonal=False --fcmaes=True --random_init=False', stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')
    p = p.replace('\r\n', '')
    print(p)
    irace_results_1.append(p)
# Out:
# 22.406943478740345
# 81.59889814894407
# 1.0187110853622734
# 2271.008260648232
# 5.374355190033626
# 137.26114985990154
# 1.0
# 1180.3012515265714
# 10000.0
# 12.406967615901037
# 0.016927027678340867
# 0.01831563888873418
# 6687534.685521223
# 11542104.80533841
# 28308.208873645402
# 2845105.03060232
# 22026.465794806718
# 2657130.347614021
# 8273393.615647721
# 1.7316788453398182
# 1.0
# 1.0
# 22.34043666690072
# 105.41069977629047
# 0.8417664724377694
# 3030.3273453238107
# 5.758539514552755
# 162.46628658565345
# 1.0
# 567.1510329878034
# 10000.0
# 12.406967615901037
# 0.03338024710862664
# 0.049787068367863944
# 12106738.126104813
# 11185948.535499526
# 638923.3709071008
# 554972.1479791399
# 442413.3920089205
# 158166.89897414244
# 12547915.608195953
# 1.0
# 1.0
# 1.0
# 79.99327069465483
# 468.335395401798
# 0.9100299935942424
# 13709.177745132378
# 5.165822080042766
# 760.9866945319638
# 1.0
# 5721.745304423825
# 10000.0
# 46.74823924521799
# 3.702131732825619
# ...

# %%
default_output = []
for rec_index, rec in df.iterrows():
    cmd = f'python target-runner.py 4 8 1101047833 yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}   --solver=CMA-ES --scale=1 --popsize_factor=3 --elitist=False --diagonal=False --fcmaes=False --random_init=False'
    p = subprocess.run(cmd, stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')
    p = p.replace('\r\n', '')
    default_output.append(p)

# %%
df_output = pd.DataFrame({'irace_1':irace_results_1,
                          'default': default_output})

# %%
df_output.to_csv('./output.csv')

# %%
irace_results_2 = []
for rec_index, rec in df.iterrows():
    cmd = f'python target-runner.py 4 8 1101047833 yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}   --solver=CMA-ES --scale=0.3177 --popsize_factor=7 --elitist=False --diagonal=False --fcmaes=True --random_init=False'
    p = subprocess.run(cmd, stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')
    p = p.replace('\r\n', '')
    irace_results_2.append(p)

# %%
irace_results_3 = []
for rec_index, rec in df.iterrows():
    cmd = f'python target-runner.py 4 8 1101047833 yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}   --solver=CMA-ES --scale=6.1404 --popsize_factor=8 --elitist=True --diagonal=False --fcmaes=False --random_init=False'
    p = subprocess.run(cmd, stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')
    p = p.replace('\r\n', '')
    irace_results_3.append(p)

# %%
irace_results_4 = []
for rec_index, rec in df.iterrows():
    cmd = f'python target-runner.py 4 8 1101047833 yasmallbbob --{rec["funct"]} --{rec["rot"]} --{rec["dim"]} --{rec["budg"]}   --solver=CMA-ES --scale=0.4267 --popsize_factor=9 --elitist=False --diagonal=False --fcmaes=True --random_init=False'
    p = subprocess.run(cmd, stdout=subprocess.PIPE, shell=True).stdout.decode('utf-8')
    p = p.replace('\r\n', '')
    irace_results_4.append(p)

# %%
df_output = pd.DataFrame({'irace_1':irace_results_1,
                          'irace_2': irace_results_2,
                          'irace_3': irace_results_3,
                          'irace_4': irace_results_4,
                          'default': default_output})

# %%
df_output.to_csv('./output_all.csv')

# %%
df_output['irace_1'] = pd.to_numeric(df_output['irace_1'])
df_output['irace_2'] = pd.to_numeric(df_output['irace_2'])
df_output['irace_3'] = pd.to_numeric(df_output['irace_3'])
df_output['irace_4'] = pd.to_numeric(df_output['irace_4'])
df_output['default'] = pd.to_numeric(df_output['default'])

# %%
df_output['Min_Col']=df_output.iloc[:,:].idxmin(1)

# %%
df_output.to_csv('./output_with_min.csv')

# %%
import collections
collections.Counter(df_output['Min_Col'].values.tolist())
# Out:
# Counter({'irace_2': 109, 'irace_1': 58, 'default': 78, 'irace_4': 19})

# %%
109 + 58 + 19
# Out:
# 186
